# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement
#
# ### Introduction
# In the United States of America (USA), students sit various entrance exams to enter college. Two popular entrance exams are the SAT and the ACT. Both exams are administered by separate non-profit organisations. The not-for-profit [College Board](https://www.collegeboard.org/) administers the SAT, while the nonprofit [ACT organisation](https://www.act.org/) administers the ACT.
#
# Students frequently sit both exams as they are both common admission requirements for USA colleges. While both of these exams [differ in content](https://blog.prepscholar.com/act-vs-sat), they are similar enough in format to make comparisons to each other thanks to a recent change in format, discussed below.
#
# To keep up with modern test-taking methodology and changes, a new format for the SAT exams was released in March 2016. [Several major changes were made](https://blog.prepscholar.com/new-sat-format-2016), such as standardising the order in which subjects were tested, as well as the amount of time and number of questions given. This mean that the format was more aligned with the ACT's.
#
# ### Project goals and why they matter
#
# In this project, I am an employee of the College Board (linked above) and need to recommend where money should be spent to improve SAT participation rates, which shows in percentage how much of the student population took that particular test. For example, an 80% participation rate in SATs in a state means that 80% of students in that state took the SAT.
#
# As such, this project aims to identify factors that affect **participation rates** and **scores** for the SAT.
#
# #### Why participation rates and scores in different states matter
#
# As [this blog post explains](https://blog.prepscholar.com/average-sat-and-act-scores-by-stated-adjusted-for-participation-rate), Participation rates matter because in states with low SAT participation have artificially higher SAT scores. This is because only highly motivated students will take the SAT and they are more likely to score higher than the average student. As such, they _bias score averages_.
#
# #### Why a biased score average for a state is detrimental
#
# As [Kate Sundquit explains](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/), Average SAT scores by state matters because the score is used to help colleges form a diverse class. One factor involved in making such a decision is by considering the geographical reason. Students compete with other students within the same state.
#
# If SAT scores are artificially high, students that scored high marks may not be accepted into the college because their score may be lower than the average. The score also affects scholarship grants, again disadvantaging those with high scores that aren't the cream of the crop.
#
# This ultimately leads to colleges accepting only the top students, which [perpetuates class inequality](https://www.cnbc.com/2019/10/03/rich-students-get-better-sat-scores-heres-why.html) as students who are top scorers generally tend to come from rich families.
#
# For these reasons, it is imperative to improve participation rates in states where participation rates are low.
#
# ## Datasets used
#
# This project uses the 2017 SAT and ACT scores datasets for data mining purposes.
#
# - [SAT 2017 Scores](./data/sat_2017.csv)
# - [SAT 2018 Scores](./data/sat_2018.csv)
# - [ACT 2017 Scores](./data/act_2017.csv)
# - [ACT 2018 Scores](./data/act_2018.csv)
#
# In addition, state-by-state average results and participation for the SAT  and SAT are referred to.
#
# - [2018 SAT reported results (HTML)](https://newsroom.collegeboard.org/more-2-million-students-class-2018-took-sat-highest-ever)
# - [2018 ACT reported results (pdf)](http://www.act.org/content/dam/act/unsecured/documents/cccr2018/Average-Scores-by-State.pdf)
#
# **This data has been compiled into CSV files which are also included in the *data* directory of this repo**

# %% [markdown]
# ## Executive Summary
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
sat_2017_url = '../data/sat_2017.csv'
act_2017_url = '../data/act_2017.csv'

sat_2017_df = pd.read_csv(sat_2017_url)
act_2017_df = pd.read_csv(act_2017_url)

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
sat_2017_df.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017_df.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_2017_df.shape
# Out:
# (51, 5)

# %%
act_2017_df.shape
# Out:
# (51, 7)

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Exploring the data and describing the data in the markdown cell below.

# %% [markdown]
# #### Exploring SAT 2017 data

# %%
sat_2017_df.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_2017_df.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# There seems to be a problem wtih the math minimum score.

# %%
#There seems to be a problem with Maryland. The Math score should be 524.
sat_2017_df[(sat_2017_df['Math']==52)]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
sat_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# #### Exploring ACT 2017 data

# %%
act_2017_df.head(5)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
#head(5) didn't show a 'National' row. Maybe the tail(5) will show it, as shown in the collegevine blog?
#After running this, there doesn't seem to be a 'National' row.
sat_2017_df.tail(5)
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           65%                                 561   541
# 47     Washington           64%                                 541   534
# 48  West Virginia           14%                                 558   528
# 49      Wisconsin            3%                                 642   649
# 50        Wyoming            3%                                 626   604
#
#     Total
# 46   1102
# 47   1075
# 48   1086
# 49   1291
# 50   1230

# %%
#Do not count the National mean and std in the scores as that is double counting. i.e. Remove first row.
act_2017_df[1:52].describe() 
#There's a problem with the minimum score of 2.3. It should most likely be 23.
# Out:
#          English       Math    Reading    Science
# count  51.000000  51.000000  51.000000  51.000000
# mean   20.931373  21.182353  22.013725  21.041176
# std     2.353677   1.981989   2.067271   3.182463
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.450000  19.900000
# 50%    20.700000  20.900000  21.800000  21.300000
# 75%    23.300000  23.100000  24.150000  22.750000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# #### Data description
#
# Answer: There are 51 entries for the SAT 2017 dataset, and 52 entries for the ACT 2017 dataset. The descripancy is due to there being an additional row in the beginning indexed as 'National' for the ACT dataset. This probably refers to the national average score of the states.
#
# There are no null/NaN cells, meaning these 2 datasets are quite clean.
#
# Data wise, ACT dataset has input floats as the scores for English, Math, Reading, and Science. Instead, the SAT dataset has input integers as the scores for their evidence based reading and writing and math.
#
# The SAT does not seem to test for science, while english and reading seem to fall under evidence based reading and writing. Math is common between the 2 exams, although their scores are different and not normalised.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Yes. There are no missing data.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# [According to the 2017 report](https://reports.collegeboard.org/pdf/2017-alabama-sat-suite-assessments-annual-report.pdf), each sub-section of the Evidence-Based Writing and Reading and Math scores have a score range between **200–800**
#
# [As shown here](https://blog.prepscholar.com/how-is-the-act-scored), each section of the ACT scores between **1-36** inclusive. These subsections feed into an overall _composite score_, also scored between **1-36**
#
# This means that the lowest score of _52_ for Math in the SAT is not possible. There was a possible data entry error when the number was being put in. As mentioned above, Maryland's Math score should be _524_.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#Set Math score for Maryland to 524.
sat_2017_df.loc[(sat_2017_df['State']=='Maryland'),'Math'] = 524

# %%
print(sat_2017_df.loc[(sat_2017_df['State']=='Maryland'),:])
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
#Set Science score for act_2017_science minimum to 23
act_2017_df.loc[(act_2017_df['Science'] == min(act_2017_df['Science'])), 'Science'] = 23

# %%
act_2017_df.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.438462
# std     2.332132   1.963602   2.048672   1.719571
# min    16.300000  18.000000  18.100000  18.200000
# 25%    19.000000  19.400000  20.475000  19.975000
# 50%    20.550000  20.900000  21.700000  21.300000
# 75%    23.300000  23.100000  24.125000  23.050000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017_df.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017_df.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: SAT 2017 dataset looks ok. So do most of the ACT 2017 dataset. However, the Composite score in ACT_2017 is an object type. This means that it's probably a string. This should not be the case as the column should be numbers.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
def participation_conversion(x):
    return float(x.strip('%'))

# %%
#Making the percentages in participation float types for sat 2017
sat_2017_df['Participation'] = sat_2017_df['Participation'].apply(participation_conversion)

# %%
act_2017_df['Participation'] = act_2017_df['Participation'].apply(participation_conversion)

# %%
#Turning the other int values in sat into floats
sat_2017_df['Math'] = [float(num) for num in sat_2017_df['Math']]
sat_2017_df['Evidence-Based Reading and Writing'] = [float(num) for num in sat_2017_df['Evidence-Based Reading and Writing']]
sat_2017_df['Total'] = [float(num) for num in sat_2017_df['Total']]

# %%
sat_2017_df.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
act_2017_df['Composite']
# Out:
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2
# 10     19.8
# 11     21.4
# 12     19.0
# 13     22.3
# 14     21.4
# 15     22.6
# 16     21.9
# 17     21.7
# 18     20.0
# 19     19.5
# 20     24.3
# 21     23.6
# 22     25.4
# 23     24.1
# 24     21.5
# 25     18.6
# 26     20.4
# 27     20.3
# 28     21.4
# 29     17.8
# 30     25.5
# 31     23.9
# 32     19.7
# 33     24.2
# 34     19.1
# 35     20.3
# 36     22.0
# 37     19.4
# 38     21.8
# 39     23.7
# 40     24.0
# 41     18.7
# 42     21.8
# 43     19.8
# 44     20.7
# 45     20.3
# 46     23.6
# 47     23.8
# 48     21.9
# 49     20.4
# 50     20.5
# 51    20.2x
# Name: Composite, dtype: object

# %% [markdown]
# There's an error in the last result, where it says _20.2x_ instead of 20.2. Time to remove the x and convert everything to float

# %%
act_2017_df.loc[51 ,'Composite' ] = 20.2

# %%
act_2017_df.loc[:,'Composite' ]= [float(composite) for composite in act_2017_df.loc[:,'Composite']]

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
sat_2017_df.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object

# %%
act_2017_df.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %% [markdown]
# Done above.

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
def sat_2017_name_changer(df):
    df = df.rename(columns= lambda x:x.lower().replace('-','_').replace(' ','_'))
    df = df.add_prefix('sat_2017_')
    df.rename(columns = {'sat_2017_state':'state'}, inplace=True)
    return df

def act_2017_name_changer(df):
    df = df.rename(columns= lambda x:x.lower().replace('-','_').replace(' ','_'))
    df = df.add_prefix('act_2017_')
    df.rename(columns = {'act_2017_state':'state'}, inplace=True)
    return df

# %%
sat_2017_df = sat_2017_name_changer(sat_2017_df)

# %%
act_2017_df = act_2017_name_changer(act_2017_df)

# %%
act_2017_df.head()
# Out:
#       state  act_2017_participation  act_2017_english  act_2017_math  \
# 0  National                    60.0              20.3           20.7
# 1   Alabama                   100.0              18.9           18.4
# 2    Alaska                    65.0              18.7           19.8
# 3   Arizona                    62.0              18.6           19.8
# 4  Arkansas                   100.0              18.9           19.0
#
#    act_2017_reading  act_2017_science  act_2017_composite
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4

# %%
sat_2017_df.head()
# Out:
#         state  sat_2017_participation  \
# 0     Alabama                     5.0
# 1      Alaska                    38.0
# 2     Arizona                    30.0
# 3    Arkansas                     3.0
# 4  California                    53.0
#
#    sat_2017_evidence_based_reading_and_writing  sat_2017_math  sat_2017_total
# 0                                        593.0          572.0          1165.0
# 1                                        547.0          533.0          1080.0
# 2                                        563.0          553.0          1116.0
# 3                                        614.0          594.0          1208.0
# 4                                        531.0          524.0          1055.0

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT|Name of State. Unlike ACT 2017, there is no national average|
# |sat_2017_participation|float|SAT|Participation rates in percentage for SAT 2017, between **0-100**|
# |sat_2017_evidence_based_reading_and_writing|float|SAT|Average Reading and Writing score for SAT 2017, between **200-800**|
# |sat_2017_math|float|SAT|Average Math score for SAT 2017, between **200-800**|
# |sat_2017_total|float|SAT|Sum of Average Math and Reading and Writing score for SAT 2017, between **400-1600**|
# |||||
# |state|object|ACT|Name of State, including National Average on row 0. This National Average is removed after cleaning|
# |act_2017_participation|float|ACT|Participation rates in percentage for ACT 2017, between **0-100**|
# |act_2017_english|float|ACT|Average English score for ACT 2017, between **1-36**|
# |act_2017_math|float|ACT|Average Math score for ACT 2017, between **1-36**|
# |act_2017_reading|float|ACT|Average reading score for ACT 2017, between **1-36**|
# |act_2017_science|float|ACT|Average science score for ACT 2017, between **1-36**|
# |act_2017_composite|float|ACT|A score composed of English, Math, Reading, and Science scores for ACT 2017, normalised to **1-36**|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
act_2017_df = act_2017_df.drop(labels=0)

# %%
act_2017_df.head()
# Out:
#         state  act_2017_participation  act_2017_english  act_2017_math  \
# 1     Alabama                   100.0              18.9           18.4
# 2      Alaska                    65.0              18.7           19.8
# 3     Arizona                    62.0              18.6           19.8
# 4    Arkansas                   100.0              18.9           19.0
# 5  California                    31.0              22.5           22.7
#
#    act_2017_reading  act_2017_science  act_2017_composite
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4
# 5              23.1              22.2                22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
merged_2017_df = pd.merge(sat_2017_df, act_2017_df, how='left')

# %%
merged_2017_df.shape
# Out:
# (51, 11)

# %%
merged_2017_df.head()
# Out:
#         state  sat_2017_participation  \
# 0     Alabama                     5.0
# 1      Alaska                    38.0
# 2     Arizona                    30.0
# 3    Arkansas                     3.0
# 4  California                    53.0
#
#    sat_2017_evidence_based_reading_and_writing  sat_2017_math  sat_2017_total  \
# 0                                        593.0          572.0          1165.0
# 1                                        547.0          533.0          1080.0
# 2                                        563.0          553.0          1116.0
# 3                                        614.0          594.0          1208.0
# 4                                        531.0          524.0          1055.0
#
#    act_2017_participation  act_2017_english  act_2017_math  act_2017_reading  \
# 0                   100.0              18.9           18.4              19.7
# 1                    65.0              18.7           19.8              20.4
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
merged_2017_df.to_csv('../data/combined_2017.csv', index=True)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#Reading the CSV files
act_2018_updated_df = pd.read_csv('../data/act_2018_updated.csv')
sat_2018_df = pd.read_csv('../data/sat_2018.csv')

# %%
act_2018_updated_df.shape
# Out:
# (51, 7)

# %%
sat_2018_df.shape
# Out:
# (51, 5)

# %% [markdown]
# The next 3 lines of code gets the first 5 rows to check headers

# %%
act_2018_updated_df.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
sat_2018_df.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %% [markdown]
# Get info for all the datasets

# %%
act_2018_updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     int64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
sat_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# Describe the datasets

# %%
sat_2018_df.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
act_2018_updated_df.describe()
# Out:
#        Percentage of Students Tested  Average Composite Score  \
# count                      51.000000                51.000000
# mean                       61.647059                21.486275
# std                        34.080976                 2.106278
# min                         7.000000                17.700000
# 25%                        28.500000                19.950000
# 50%                        66.000000                21.300000
# 75%                       100.000000                23.550000
# max                       100.000000                25.600000
#
#        Average English Score  Average Math Score  Average Reading Score  \
# count              51.000000           51.000000              51.000000
# mean               20.988235           21.125490              22.015686
# std                 2.446356            2.035765               2.167245
# min                16.600000           17.800000              18.000000
# ...

# %% [markdown]
# Everything seems in order

# %% [markdown]
# Define similar functions as in 2017 to edit the names

# %%
def sat_2018_name_changer(df):
    df = df.rename(columns= lambda x:x.lower().replace('-','_').replace(' ','_'))
    df = df.add_prefix('sat_2018_')
    df.rename(columns = {'sat_2018_state':'state'}, inplace=True)
    return df

def act_2018_updated_name_changer(df):
    df = df.rename(columns= lambda x:x.lower().replace('-','_').replace(' ','_'))
    df = df.add_prefix('act_2018_')
    df.rename(columns = {'act_2018_state':'state'}, inplace=True)
    df.rename(columns = {'act_2018_percentage_of_students_tested': 'act_2018_participation'}, inplace=True)
    return df

# %%
sat_2018_df = sat_2018_name_changer(sat_2018_df)

# %%
act_2018_updated_df = act_2018_updated_name_changer(act_2018_updated_df)

# %%
sat_2018_df.dtypes
# Out:
# state                                          object
# sat_2018_participation                         object
# sat_2018_evidence_based_reading_and_writing     int64
# sat_2018_math                                   int64
# sat_2018_total                                  int64
# dtype: object

# %% [markdown]
# Turn the participation column into float with participation_conversion() and .apply() method

# %%
sat_2018_df['sat_2018_participation'] = sat_2018_df['sat_2018_participation'].apply(participation_conversion)

# %%
act_2018_updated_df['act_2018_participation'] = act_2018_updated_df['act_2018_participation'].apply(lambda x: float(x))

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
combined_sat_2018 = pd.merge(merged_2017_df, sat_2018_df, how='left')
final_df = pd.merge(combined_sat_2018, act_2018_updated_df, how='left')

# %%
final_df.shape
# Out:
# (51, 21)

# %%
final_df.head()
# Out:
#         state  sat_2017_participation  \
# 0     Alabama                     5.0
# 1      Alaska                    38.0
# 2     Arizona                    30.0
# 3    Arkansas                     3.0
# 4  California                    53.0
#
#    sat_2017_evidence_based_reading_and_writing  sat_2017_math  sat_2017_total  \
# 0                                        593.0          572.0          1165.0
# 1                                        547.0          533.0          1080.0
# 2                                        563.0          553.0          1116.0
# 3                                        614.0          594.0          1208.0
# 4                                        531.0          524.0          1055.0
#
#    act_2017_participation  act_2017_english  act_2017_math  act_2017_reading  \
# 0                   100.0              18.9           18.4              19.7
# 1                    65.0              18.7           19.8              20.4
# ...

# %%
final_df.dtypes
# Out:
# state                                           object
# sat_2017_participation                         float64
# sat_2017_evidence_based_reading_and_writing    float64
# sat_2017_math                                  float64
# sat_2017_total                                 float64
# act_2017_participation                         float64
# act_2017_english                               float64
# act_2017_math                                  float64
# act_2017_reading                               float64
# act_2017_science                               float64
# act_2017_composite                             float64
# sat_2018_participation                         float64
# sat_2018_evidence_based_reading_and_writing      int64
# sat_2018_math                                    int64
# sat_2018_total                                   int64
# act_2018_participation                         float64
# act_2018_average_composite_score               float64
# ...

# %%
final_df.to_csv('../data/final.csv', index=True)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final_df.describe()
# Out:
#        sat_2017_participation  sat_2017_evidence_based_reading_and_writing  \
# count               51.000000                                    51.000000
# mean                39.803922                                   569.117647
# std                 35.276632                                    45.666901
# min                  2.000000                                   482.000000
# 25%                  4.000000                                   533.500000
# 50%                 38.000000                                   559.000000
# 75%                 66.000000                                   613.000000
# max                100.000000                                   644.000000
#
#        sat_2017_math  sat_2017_total  act_2017_participation  \
# count      51.000000       51.000000               51.000000
# mean      556.882353     1126.098039               65.254902
# std        47.121395       92.494812               32.140842
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def standard_dev(column):
    #Initialise summed_x as 0 to collect sum of all x later
    summed_x = 0
    
    normalised_x_list = mu(column)
    for x in normalised_x_list:
        summed_x += x
    sd = (summed_x/len(column))**0.5
    return sd
    
# Helper function to calculate mean_mu
def mu(column):
    total_x = 0
    for _, x in column.items():
        total_x += x
    mean_mu = (total_x/len(column))
    normalised_x_sqr = [(x-mean_mu)**2 for _,x in column.items()]
    return(normalised_x_sqr)

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {column:standard_dev(final_df[column]) for column in final_df.iloc[:,1::]}
print(sd)
# Out:
# {'sat_2017_participation': 34.92907076664508, 'sat_2017_evidence_based_reading_and_writing': 45.21697020437866, 'sat_2017_math': 46.65713364485503, 'sat_2017_total': 91.58351056778743, 'act_2017_participation': 31.824175751231806, 'act_2017_english': 2.3304876369363363, 'act_2017_math': 1.9624620273436781, 'act_2017_reading': 2.0469029314842646, 'act_2017_science': 1.7184526716715494, 'act_2017_composite': 2.000786081581989, 'sat_2018_participation': 36.946619223539415, 'sat_2018_evidence_based_reading_and_writing': 47.03460978357609, 'sat_2018_math': 47.30194550378352, 'sat_2018_total': 93.22742384464433, 'act_2018_participation': 33.745194881997506, 'act_2018_average_composite_score': 2.0855261815801147, 'act_2018_average_english_score': 2.4222536143202795, 'act_2018_average_math_score': 2.015707255555717, 'act_2018_average_reading_score': 2.145891884510421, 'act_2018_average_science_score': 1.8516885484833543}

# %% [markdown]
# Q: Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Method: `Describe` results are shown above. Let's do numpy's `std` method in the cell below

# %%
[print({column: np.std(final_df[column])}) for column in final_df.iloc[:,1::]];
# Out:
# {'sat_2017_participation': 34.92907076664508}
# {'sat_2017_evidence_based_reading_and_writing': 45.21697020437866}
# {'sat_2017_math': 46.65713364485503}
# {'sat_2017_total': 91.58351056778743}
# {'act_2017_participation': 31.824175751231806}
# {'act_2017_english': 2.3304876369363363}
# {'act_2017_math': 1.9624620273436781}
# {'act_2017_reading': 2.0469029314842646}
# {'act_2017_science': 1.7184526716715494}
# {'act_2017_composite': 2.000786081581989}
# {'sat_2018_participation': 36.946619223539415}
# {'sat_2018_evidence_based_reading_and_writing': 47.03460978357609}
# {'sat_2018_math': 47.30194550378352}
# {'sat_2018_total': 93.22742384464433}
# {'act_2018_participation': 33.745194881997506}
# {'act_2018_average_composite_score': 2.0855261815801147}
# {'act_2018_average_english_score': 2.4222536143202795}
# {'act_2018_average_math_score': 2.015707255555717}
# {'act_2018_average_reading_score': 2.145891884510421}
# {'act_2018_average_science_score': 1.8516885484833543}

# %% [markdown]
# Answer:
#
# My standard_dev function does not give the same answer as pandas' `describe` method, but it gives exactly the same results as numpy's `std` method.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Highest SAT 2017 participation rates
final_df.sort_values(by=['sat_2017_participation'], ascending=False).head(10)
# Out:
#                    state  sat_2017_participation  \
# 8   District of Columbia                   100.0
# 22              Michigan                   100.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 29         New Hampshire                    96.0
# 19                 Maine                    95.0
# 12                 Idaho                    93.0
# 9                Florida                    83.0
# 21         Massachusetts                    76.0
# 39          Rhode Island                    71.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 8                                         482.0          468.0
# 22                                        509.0          495.0
# 6                                         530.0          512.0
# 7                                         503.0          492.0
# 29                                        532.0          520.0
# ...

# %% [markdown]
# Highest SAT 2017 participation rates
#
# 4 of these states have a 100% participation rate. New Hampshire is the exception, with a 96% participation rate.
#
# An interesting feature is that their ACT 2017 participation rates are quite low, between 18-38%, with Florida being a major exception, having a high participation rate for both SAT and ACT, at 83% and 73% respectively. This will turn up in the analysis looking for states with relatively high SAT and ACT rates.

# %%
#Lowest SAT 2017 participation rates
final_df.sort_values(by=['sat_2017_participation'], ascending=False).tail(10)
# Out:
#            state  sat_2017_participation  \
# 49     Wisconsin                     3.0
# 25      Missouri                     3.0
# 41  South Dakota                     3.0
# 27      Nebraska                     3.0
# 23     Minnesota                     3.0
# 3       Arkansas                     3.0
# 50       Wyoming                     3.0
# 34  North Dakota                     2.0
# 24   Mississippi                     2.0
# 15          Iowa                     2.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 49                                        642.0          649.0
# 25                                        640.0          631.0
# 41                                        612.0          603.0
# 27                                        629.0          625.0
# 23                                        644.0          651.0
# 3                                         614.0          594.0
# ...

# %% [markdown]
# Lowest SAT 2017 participation rates
#
# These 10 states have the lowest participation rates for the SAT in 2017, all having a 2-3% participation rate.
#
# These states have a high ACT participation rate though, with ACT 2017 participation rates between 98-100% for most them. The exception, and this warrants further investigation, is Iowa, with an ACT participation rate of 67%. This is interesting because this means that Iowa students don't seem to be taking either the SAT or the ACT. Perhaps there's a less common test that they're taking?
#
# This applies to a lesser extent to South Dakota and Nebraska, with an ACT 2017 participation rate of 80% and 84% respectively.
#
# Note that the averages for these 5 states have a higher score average for the SAT exam components, with the average being about 100-150 more than the states with a high SAT participation rate. This is in line with the problem statement defined at the start of this notebook, where only the highly motivated students take the tests, resulting in higher national averages.

# %%
#Highest SAT 2018 participation rates
pd.set_option('display.max_columns', None)
final_df.sort_values(by=['sat_2018_participation'], ascending=False).head(10)
# Out:
#                    state  sat_2017_participation  \
# 5               Colorado                    11.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 22              Michigan                   100.0
# 12                 Idaho                    93.0
# 19                 Maine                    95.0
# 13              Illinois                     9.0
# 39          Rhode Island                    71.0
# 29         New Hampshire                    96.0
# 8   District of Columbia                   100.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 5                                         606.0          595.0
# 6                                         530.0          512.0
# 7                                         503.0          492.0
# 22                                        509.0          495.0
# 12                                        513.0          493.0
# ...

# %% [markdown]
# Highest SAT 2018 participation rates
#
# These 10 states all have above 90% SAT participation rates for 2018, which is much more than the 7 states that had above 90% SAT participation rates in 2017. Perhaps with more experience and a collection of past papers available, students are brave enough to tackle the new SAT format?
#
# As before, they all have low ACT 2018 participation rates, ranging between 17%-36%, which is about the same as the states with high SAT participation rates in 2017, 18%-32%.
#
# The students seem to have improved in their averages. the sat_2018_evidence_based_reading_and_writing and sat_2018_math scores have a higher score floor than their 2017 scores. For example, the lowest score among those with 100% participation rates in 2017 for math was the District of Columbia, with 468%, while the lowest in 2018 for math is Delaware, with a score of 492.
#
# Interestingly, Michigan, Conneticut, Delaware are both had 100% SAT participation rates for 2017 and 2018, while Colorado and Idaho beat District of Columbia and New Hampshire in 2018.

# %%
#Lowest SAT 2018 participation rates
final_df.sort_values(by=['sat_2018_participation'], ascending=False).tail(10)
# Out:
#            state  sat_2017_participation  \
# 18     Louisiana                     4.0
# 17      Kentucky                     4.0
# 16        Kansas                     4.0
# 41  South Dakota                     3.0
# 27      Nebraska                     3.0
# 24   Mississippi                     2.0
# 15          Iowa                     2.0
# 49     Wisconsin                     3.0
# 50       Wyoming                     3.0
# 34  North Dakota                     2.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 18                                        611.0          586.0
# 17                                        631.0          616.0
# 16                                        632.0          628.0
# 41                                        612.0          603.0
# 27                                        629.0          625.0
# 24                                        634.0          607.0
# ...

# %% [markdown]
# Lowest SAT 2018 participation rates
#
# Once again all these states have a low SAT participation rate for 2018 of between 2-3%.
#
# Again, Iowa has a lower ACT participation score than usual, further reinforcing the need for further investigation.

# %%
#Highest ACT 2017 participation rates using Masking
final_df[final_df['act_2017_participation']>90].head(10)
# Out:
#           state  sat_2017_participation  \
# 0       Alabama                     5.0
# 3      Arkansas                     3.0
# 5      Colorado                    11.0
# 13     Illinois                     9.0
# 17     Kentucky                     4.0
# 18    Louisiana                     4.0
# 23    Minnesota                     3.0
# 24  Mississippi                     2.0
# 25     Missouri                     3.0
# 26      Montana                    10.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 0                                         593.0          572.0
# 3                                         614.0          594.0
# 5                                         606.0          595.0
# 13                                        559.0          556.0
# 17                                        631.0          616.0
# 18                                        611.0          586.0
# 23                                        644.0          651.0
# ...

# %% [markdown]
# Highest ACT 2017 participation rates
#
# These 10 states follow the trend we discovered in the above data for SAT participation rates, where states with a high ACT participation rate have low SAT participation rate.
#
# The states with high 2017 SAT rates had participation rates between 18-38% for ACT 2017. These states with high 2017 ACT rates had a lower 2017 SAT participation rate, ranging between 2%-11%. Again, 2017 was the first year with major changes, so perhaps students were discouraged from taking the SAT for the first year.

# %%
#Lowest ACT 2017 participation rates
final_df[final_df['act_2017_participation']<40].head(10)
# Out:
#                    state  sat_2017_participation  \
# 4             California                    53.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 8   District of Columbia                   100.0
# 12                 Idaho                    93.0
# 14               Indiana                    63.0
# 19                 Maine                    95.0
# 20              Maryland                    69.0
# 21         Massachusetts                    76.0
# 22              Michigan                   100.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 4                                         531.0          524.0
# 6                                         530.0          512.0
# 7                                         503.0          492.0
# 8                                         482.0          468.0
# 12                                        513.0          493.0
# ...

# %% [markdown]
# Lowest ACT 2017 participation rates
#
# The relatively high threshold of 40 that I put for the mask in the code above is because when I tried a lower threshold of 20, only 3 states appeared!
#
# It seems the ACT was popular in 2017, even though these states all had relatively high participation rates for the SAT in 2017. California is a strange exception, with a middling participation rate of 31% for ACT and 53% for SAT.
#
# From my cursory knowledge of California, this is surprising to me as California is a technological hub with several good universities. I would've expected the technology culture there to have trickled down to the public. Perhaps the education system and the culture around them are disconnected? This warrants further investigation.
#
# Once again there is a slightly higher average in scores for these states, compared to the states with a high ACT participation rate. Averages are approximately 3% or so higher.

# %%
#Highest ACT 2018 participation rates
final_df[final_df['act_2018_participation']>80].head(10)
# Out:
#           state  sat_2017_participation  \
# 0       Alabama                     5.0
# 3      Arkansas                     3.0
# 11       Hawaii                    55.0
# 17     Kentucky                     4.0
# 18    Louisiana                     4.0
# 23    Minnesota                     3.0
# 24  Mississippi                     2.0
# 25     Missouri                     3.0
# 26      Montana                    10.0
# 27     Nebraska                     3.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 0                                         593.0          572.0
# 3                                         614.0          594.0
# 11                                        544.0          541.0
# 17                                        631.0          616.0
# 18                                        611.0          586.0
# 23                                        644.0          651.0
# 24                                        634.0          607.0
# ...

# %% [markdown]
# Highest ACT 2018 participation rates
#
# Once again, all these states have a low SAT participation rate for 2018, except for Hawaii, with a very high participation rate of 56% for the SAT in 2018! This requires looking into.
#
# I have some familiarity with Hawaii for other reasons. I know that there is a large group of Asians, particularly Japanese. It is also an island separate from the mainland. These 2 facts may be relevant when looking into the reasons that its students take these 2 tests.

# %%
#Lowest ACT 2018 participation rates
final_df[final_df['act_2018_participation']<40].head(10)
# Out:
#                    state  sat_2017_participation  \
# 1                 Alaska                    38.0
# 4             California                    53.0
# 5               Colorado                    11.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 8   District of Columbia                   100.0
# 12                 Idaho                    93.0
# 14               Indiana                    63.0
# 19                 Maine                    95.0
# 20              Maryland                    69.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 1                                         547.0          533.0
# 4                                         531.0          524.0
# 5                                         606.0          595.0
# 6                                         530.0          512.0
# 7                                         503.0          492.0
# ...

# %% [markdown]
# Lowest ACT 2018 participation rates
#
# Again it seems that the ACT is popular even among states that prefer to take the SAT. Alaska, California, and Indiana are exceptions with low SAT and ACT scores.

# %% [markdown]
# ## Overall comments for participation rates
#
# I think states having a low ACT participation rate is more alarming than states with a very low SAT participation rate of between 2-3%, since those states seem to have high ACT participation rates. I would look into states with middling ACT participation rates, as it's more likely that there's a middling SAT score.
#
# Now, assuming states have a 50% participation rate in both exams, perhaps this means that half the state is taking one exam, and the other half is taking the other exam. This, however, is the optimistic scenario. I recommend we take the more pessimistic view that only half the student population is taking both exams. This would suggest a wide gap in student quality.

# %% [markdown]
# ---------------------------
#
# - Which states have the highest and lowest mean total/composite scores for the:
#
#    -  2017 SAT?
#    -  2018 SAT?
#    -  2017 ACT?
#    -  2018 ACT?

# %%
final_df[final_df['sat_2017_total']==max(final_df['sat_2017_total'])]
# Out:
#         state  sat_2017_participation  \
# 23  Minnesota                     3.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 23                                        644.0          651.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 23          1295.0                   100.0              20.4           21.5
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 23              21.8              21.6                21.5
#
#     sat_2018_participation  sat_2018_evidence_based_reading_and_writing  \
# 23                     4.0                                          643
#
#     sat_2018_math  sat_2018_total  act_2018_participation  \
# 23            655            1298                    99.0
#
#     act_2018_average_composite_score  act_2018_average_english_score  \
# 23                              21.3                            20.2
#
# ...

# %%
final_df[final_df['sat_2017_total']==min(final_df['sat_2017_total'])]
# Out:
#                   state  sat_2017_participation  \
# 8  District of Columbia                   100.0
#
#    sat_2017_evidence_based_reading_and_writing  sat_2017_math  sat_2017_total  \
# 8                                        482.0          468.0           950.0
#
#    act_2017_participation  act_2017_english  act_2017_math  act_2017_reading  \
# 8                    32.0              24.4           23.5              24.9
#
#    act_2017_science  act_2017_composite  sat_2018_participation  \
# 8              23.5                24.2                    92.0
#
#    sat_2018_evidence_based_reading_and_writing  sat_2018_math  sat_2018_total  \
# 8                                          497            480             977
#
#    act_2018_participation  act_2018_average_composite_score  \
# 8                    32.0                              23.6
#
#    act_2018_average_english_score  act_2018_average_math_score  \
# 8                            23.7                         22.7
#
# ...

# %%
final_df[final_df['sat_2018_total']==max(final_df['sat_2018_total'])]
# Out:
#         state  sat_2017_participation  \
# 23  Minnesota                     3.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 23                                        644.0          651.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 23          1295.0                   100.0              20.4           21.5
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 23              21.8              21.6                21.5
#
#     sat_2018_participation  sat_2018_evidence_based_reading_and_writing  \
# 23                     4.0                                          643
#
#     sat_2018_math  sat_2018_total  act_2018_participation  \
# 23            655            1298                    99.0
#
#     act_2018_average_composite_score  act_2018_average_english_score  \
# 23                              21.3                            20.2
#
# ...

# %%
final_df[final_df['sat_2018_total']==min(final_df['sat_2018_total'])]
# Out:
#                   state  sat_2017_participation  \
# 8  District of Columbia                   100.0
#
#    sat_2017_evidence_based_reading_and_writing  sat_2017_math  sat_2017_total  \
# 8                                        482.0          468.0           950.0
#
#    act_2017_participation  act_2017_english  act_2017_math  act_2017_reading  \
# 8                    32.0              24.4           23.5              24.9
#
#    act_2017_science  act_2017_composite  sat_2018_participation  \
# 8              23.5                24.2                    92.0
#
#    sat_2018_evidence_based_reading_and_writing  sat_2018_math  sat_2018_total  \
# 8                                          497            480             977
#
#    act_2018_participation  act_2018_average_composite_score  \
# 8                    32.0                              23.6
#
#    act_2018_average_english_score  act_2018_average_math_score  \
# 8                            23.7                         22.7
#
# ...

# %% [markdown]
# I saved my analysis of both SAT 2017 and 2018 scores together. For the SAT 2017 and 2018 exam, Minnesota has the highest mean total score of 1295 and 1298 respectively, while District of Columbia had the lowest mean score of 950 and 977 respectively. It's no surprise that the same state holds the same position for 2 years because, barring any major events, it will take time for any major changes to be made.

# %%
final_df[final_df['act_2017_composite']==max(final_df['act_2017_composite'])]
# Out:
#             state  sat_2017_participation  \
# 29  New Hampshire                    96.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 29                                        532.0          520.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 29          1052.0                    18.0              25.4           25.1
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 29              26.0              24.9                25.5
#
#     sat_2018_participation  sat_2018_evidence_based_reading_and_writing  \
# 29                    96.0                                          535
#
#     sat_2018_math  sat_2018_total  act_2018_participation  \
# 29            528            1063                    16.0
#
#     act_2018_average_composite_score  act_2018_average_english_score  \
# 29                              25.1                            25.1
#
# ...

# %%
final_df[final_df['act_2018_average_composite_score']==max(final_df['act_2018_average_composite_score'])]
# Out:
#          state  sat_2017_participation  \
# 6  Connecticut                   100.0
#
#    sat_2017_evidence_based_reading_and_writing  sat_2017_math  sat_2017_total  \
# 6                                        530.0          512.0          1041.0
#
#    act_2017_participation  act_2017_english  act_2017_math  act_2017_reading  \
# 6                    31.0              25.5           24.6              25.6
#
#    act_2017_science  act_2017_composite  sat_2018_participation  \
# 6              24.6                25.2                   100.0
#
#    sat_2018_evidence_based_reading_and_writing  sat_2018_math  sat_2018_total  \
# 6                                          535            519            1053
#
#    act_2018_participation  act_2018_average_composite_score  \
# 6                    26.0                              25.6
#
#    act_2018_average_english_score  act_2018_average_math_score  \
# 6                            26.0                         24.8
#
# ...

# %%
final_df[final_df['act_2017_composite']==min(final_df['act_2017_composite'])]
# Out:
#      state  sat_2017_participation  \
# 28  Nevada                    26.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 28                                        563.0          553.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 28          1116.0                   100.0              16.3           18.0
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 28              18.1              18.2                17.8
#
#     sat_2018_participation  sat_2018_evidence_based_reading_and_writing  \
# 28                    23.0                                          574
#
#     sat_2018_math  sat_2018_total  act_2018_participation  \
# 28            566            1140                   100.0
#
#     act_2018_average_composite_score  act_2018_average_english_score  \
# 28                              17.7                            16.6
#
#     act_2018_average_math_score  act_2018_average_reading_score  \
# ...

# %%
final_df[final_df['act_2018_average_composite_score']==min(final_df['act_2018_average_composite_score'])]
# Out:
#      state  sat_2017_participation  \
# 28  Nevada                    26.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 28                                        563.0          553.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 28          1116.0                   100.0              16.3           18.0
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 28              18.1              18.2                17.8
#
#     sat_2018_participation  sat_2018_evidence_based_reading_and_writing  \
# 28                    23.0                                          574
#
#     sat_2018_math  sat_2018_total  act_2018_participation  \
# 28            566            1140                   100.0
#
#     act_2018_average_composite_score  act_2018_average_english_score  \
# 28                              17.7                            16.6
#
#     act_2018_average_math_score  act_2018_average_reading_score  \
# ...

# %% [markdown]
# Nevada was the lowest scoring state for the ACTs in 2017 (17.8) and 2018 (17.7). New Hampshire had the highest ACT score in 2017 (25.5), while Connecticut barely overtook it in 2018 (25.6). Perhaps the normalisation of scores makes it such that only a narrow gap exists between the first and second best states.

# %% [markdown]
# - Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
#Check for ACT 2017 participation rates ==100 and 2018 participation rates <100
final_df[(final_df['act_2017_participation']==100) & (final_df['act_2018_participation']<100)]
# Out:
#         state  sat_2017_participation  \
# 5    Colorado                    11.0
# 23  Minnesota                     3.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 5                                         606.0          595.0
# 23                                        644.0          651.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 5           1201.0                   100.0              20.1           20.3
# 23          1295.0                   100.0              20.4           21.5
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 5               21.2              20.9                20.8
# 23              21.8              21.6                21.5
#
#     sat_2018_participation  sat_2018_evidence_based_reading_and_writing  \
# 5                    100.0                                          519
# 23                     4.0                                          643
#
# ...

# %%
#Check for SAT 2017 participation rates ==100 and 2018 participation rates <100
final_df[(final_df['sat_2017_participation']==100) & (final_df['sat_2018_participation']<100)]
# Out:
#                   state  sat_2017_participation  \
# 8  District of Columbia                   100.0
#
#    sat_2017_evidence_based_reading_and_writing  sat_2017_math  sat_2017_total  \
# 8                                        482.0          468.0           950.0
#
#    act_2017_participation  act_2017_english  act_2017_math  act_2017_reading  \
# 8                    32.0              24.4           23.5              24.9
#
#    act_2017_science  act_2017_composite  sat_2018_participation  \
# 8              23.5                24.2                    92.0
#
#    sat_2018_evidence_based_reading_and_writing  sat_2018_math  sat_2018_total  \
# 8                                          497            480             977
#
#    act_2018_participation  act_2018_average_composite_score  \
# 8                    32.0                              23.6
#
#    act_2018_average_english_score  act_2018_average_math_score  \
# 8                            23.7                         22.7
#
# ...

# %% [markdown]
# Colorado and Minnesota had 100% ACT participation rates in 2017, but fell below 100% in 2018. Similarly, the District of Columbia had 100% SAT participation rate in 2017, but not in 2018.

# %% [markdown]
# - Do any states show have >50% participation on both tests either year?

# %%
final_df[(final_df['act_2017_participation']>50) & (final_df['sat_2017_participation']>50)]
# Out:
#       state  sat_2017_participation  \
# 9   Florida                    83.0
# 10  Georgia                    61.0
# 11   Hawaii                    55.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 9                                         520.0          497.0
# 10                                        535.0          515.0
# 11                                        544.0          541.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 9           1017.0                    73.0              19.0           19.4
# 10          1050.0                    55.0              21.0           20.9
# 11          1085.0                    90.0              17.8           19.2
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 9               21.0              19.4                19.8
# 10              22.0              21.3                21.4
# 11              19.2              19.3                19.0
#
# ...

# %%
final_df[(final_df['act_2018_participation']>50) & (final_df['sat_2018_participation']>50)]
# Out:
#              state  sat_2017_participation  \
# 9          Florida                    83.0
# 10         Georgia                    61.0
# 11          Hawaii                    55.0
# 33  North Carolina                    49.0
# 40  South Carolina                    50.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 9                                         520.0          497.0
# 10                                        535.0          515.0
# 11                                        544.0          541.0
# 33                                        546.0          535.0
# 40                                        543.0          521.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 9           1017.0                    73.0              19.0           19.4
# 10          1050.0                    55.0              21.0           20.9
# 11          1085.0                    90.0              17.8           19.2
# ...

# %% [markdown]
# Hawaii, Georgia, and Florida all show up in 2017 with more than 50% participation rates in both exams. They maintain their position in 2018, with North and South Carolina joining the list.

# %% [markdown]
# Personal check: What states show <50% participation rates for both tests either year?

# %%
final_df[(final_df['act_2017_participation']<50) & (final_df['sat_2017_participation']<50)]
# Out:
#      state  sat_2017_participation  \
# 37  Oregon                    43.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 37                                        560.0          548.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 37          1108.0                    40.0              21.2           21.5
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 37              22.4              21.7                21.8
#
#     sat_2018_participation  sat_2018_evidence_based_reading_and_writing  \
# 37                    48.0                                          564
#
#     sat_2018_math  sat_2018_total  act_2018_participation  \
# 37            553            1117                    42.0
#
#     act_2018_average_composite_score  act_2018_average_english_score  \
# 37                              21.3                            20.6
#
#     act_2018_average_math_score  act_2018_average_reading_score  \
# ...

# %%
final_df[(final_df['act_2018_participation']<50) & (final_df['sat_2018_participation']<50)]
# Out:
#      state  sat_2017_participation  \
# 1   Alaska                    38.0
# 37  Oregon                    43.0
#
#     sat_2017_evidence_based_reading_and_writing  sat_2017_math  \
# 1                                         547.0          533.0
# 37                                        560.0          548.0
#
#     sat_2017_total  act_2017_participation  act_2017_english  act_2017_math  \
# 1           1080.0                    65.0              18.7           19.8
# 37          1108.0                    40.0              21.2           21.5
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 1               20.4              19.9                19.8
# 37              22.4              21.7                21.8
#
#     sat_2018_participation  sat_2018_evidence_based_reading_and_writing  \
# 1                     43.0                                          562
# 37                    48.0                                          564
#
# ...

# %% [markdown]
# Oregon in 2017 and 2018 and Alaska in 2018 had less than 50% participation rates for both the SAT and ACT.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# ax = plt.axes()
# ax.set_title('Heatmap between every numerical variable in final_df')
# plt.subplots(figsize=(10,10))
plt.figure(figsize=(15,12))
plt.title('Heatmap between every numerical variable in final_df')
sns.heatmap(final_df.corr(), annot=True);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, constrained_layout=True, figsize = (10,20))
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
    for i, title_column in enumerate(list_of_titles):
        ax[i].set_title(title_column)
    for i, xlabel_column in enumerate(list_of_xlabels): 
        ax[i].set_xlabel(xlabel_column)
    for i, ylabel_column in enumerate(list_of_ylabels):
        ax[i].set_ylabel(ylabel_column)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
column_input = ['sat_2017_participation', 'act_2017_participation', 'sat_2018_participation', 'act_2018_participation',
              'sat_2017_math', 'act_2017_math', 'sat_2018_math', 'act_2018_average_math_score', 
               'sat_2017_evidence_based_reading_and_writing', 'act_2018_average_reading_score']
column_title = column_input
column_xlabel = ['Participation rates', 'Participation rates', 'Participation rates', 'Participation rates',
               'SAT Math scores', 'ACT Math scores', 'SAT Math scores', 'ACT Math scores',
               'SAT Reading and Writing scores', 'ACT reading scores']
column_ylabel = ['Frequency', 'Frequency', 'Frequency', 'Frequency',
                 'No. of states', 'No. of states', 'No. of states', 'No. of states',
                  'No. of states', 'No. of states']

subplot_histograms(final_df, column_input, column_title, column_xlabel, column_ylabel)

# %% [markdown]
# For Math and Reading (The 6 histograms at the last 3 rows), there are 2 peaks, suggesting a multimodal distribution. This is true for all the graphs except participation rates, which seem to come from some exponential distribution.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def subplot_scatterplot(dataframe, x_data, y_data, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows=int(np.ceil(len(x_data)/2))
    fig, ax = plt.subplots(nrows=nrows, ncols=2, constrained_layout=True, figsize = (10,10))
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(x_data):
        ax[i].scatter(dataframe[x_data[i]], dataframe[y_data[i]])
    for i, title_column in enumerate(list_of_titles):
        ax[i].set_title(title_column)
    for i, xlabel_column in enumerate(list_of_xlabels): 
        ax[i].set_xlabel(xlabel_column)
    for i, ylabel_column in enumerate(list_of_ylabels):
        ax[i].set_ylabel(ylabel_column)

# %%
x_data = ['sat_2017_math', 'sat_2017_evidence_based_reading_and_writing', 'sat_2017_total', 'sat_2017_total',
         'act_2017_composite']
y_data = ['act_2017_math', 'act_2017_reading', 'act_2017_composite', 'act_2018_average_composite_score',
         'act_2018_average_composite_score']
column_title_2 = ['SAT vs ACT 2017 Math scores', 'SAT vs ACT 2017 reading/verbal scores', 
                'SAT vs ACT 2017 total scores', 'SAT 2017 vs ACT 2018 total scores', 'ACT 2017 vs 2018 composite scores']
x_label_2 = x_data
y_label_2 = y_data


subplot_scatterplot(final_df, x_data=x_data, y_data=y_data, list_of_titles=column_title_2, list_of_xlabels=x_label_2, 
                    list_of_ylabels=y_label_2)

# %% [markdown]
# ACT 2017 and 2018 composite scores have an almost perfect correlation, with 2 outliers in the middle that scored about 1-2 marks better for 2018 than 2017. For the rest, there doesn't seem to be a _linear_ correlation. However, they do seem to vaguely follow a non-linear correlation (something like an x squared). The variation seems very wide though.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
'''
Input: A dataframe of Series composed of numerical values
Output: Several boxplots with values on the same numerical scale plotted together
Method: My method relies on the fact that the median lies in similar areas per plot.
I use conditionals. 'If median falls between 400-800, plot this column on this particular scale'
'''

def subplot_box(dataframe):
    #Create subplots and set different y scales for each
    #Reference  https://stackoverflow.com/questions/46933824/matplotlib-adding-an-axes-using-the-same-arguments-as-a-previous-axes
    fig, ax = plt.subplots(4, 1, figsize=(20,20))
    
    #Initialise arrays to append with column name later
    array_1000=[]
    array_400=[]
    array_40=[]
    array_0=[]
    
    #Iterate through the columns and grab data, then separate them into categories and graph them.
    #Problem: They're overlapping
    
    for column in dataframe.columns:
        column_median = dataframe[column].median()

        if column_median > 1000:
            #Put into graph with scale 900-1400
            #First, add column into array, then give that array into the dataframe as output
            array_1000.append(column)
            sns.boxplot(data=dataframe[array_1000], ax = ax[0],
                       orient='h')
            
        elif (column_median>400 and column_median<800):
            #Put into graph with scale 400-700
            array_400.append(column)
            sns.boxplot(data=dataframe[array_400], ax = ax[1],
                       orient='h')
     
        elif (column_median>36 and column_median<399):
            #Put into graph with scale 40-150
            array_40.append(column)
            sns.boxplot(data=dataframe[array_40],  ax = ax[2],
                       orient='h')
           
        else:
            #Put into graph with scale 0-40
            array_0.append(column)
            sns.boxplot(data=dataframe[array_0],  ax=ax[3],
                       orient='h')
    ax[0].plot()
    ax[1].plot()
    ax[2].plot()
    ax[3].plot()

# %%
subplot_box(final_df.iloc[:,1::])

# %% [markdown]
# The most interesting plot is the 3rd one from the top, which compares participation rates against one another. There were more students who took the ACT than the SAT in both years. However, there was a big jump in participation rates for SAT 2018, perhaps because more students became more confident with the new format.
#
# From the 2nd plot from the top, we see that scores dropped for the SAT from 2017 to 2018. Perhaps the markers became more strict in their marking. This is reinforced by the 1st plot, which shows the total scores for the SAT dropping from 2017 to 2018.
#
# From the 4th plot, you see that the average composite scores remained the same for ACT. There seems to be a big range for English scores, so it might be worth investigating why some students get much more than the others.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# For the **participation rates**, both 2017 and 2018 and for ACT and SAT, the distributions seemed to mirror one another. You can see this from the histogram above. They seem to have been taken from an exponential distribution that is skewed to the right. From the 3rd boxplot, you can see that more people took the ACT than the SAT, with the ACT clearly having higher participation rates. The median for the SAT and ACT participation rates are as follows:
#
# **_Participation rates_**
# - **SAT 2017**: Median: 38.0|  Mean: 39.8
# - **SAT 2018**: Median: 52.0|  Mean: 45.7
# - **ACT 2017**: Median: 69.0|  Mean: 65.3
# - **ACT 2018**: Median: 66.0|  Mean: 61.7
#
#
# For the **Math and Reading scores**, you can see from the histograms that they have 2 peaks, following a multimodal distribution. From the scattergraphs it seems that the SAT and ACT scores are correlated non-linearly, but with a large variation.
#
# ### **Scores**
#
# **_Total/Composite (SAT: Total, ACT: Composite)_**
# - **SAT 2017**: Median: 1107.0| Mean: 1126.1
# - **SAT 2018**: Median: 1098.0| Mean: 1120.0
# - **ACT 2017**: Median: 21.4  | Mean: 21.5
# - **ACT 2018**: Median: 21.3  | Mean: 21.5
#
# **_Maths (SAT and ACT)_**
# - **SAT 2017**: Median: 548.0| Mean: 556.8
# - **SAT 2018**: Median: 544.0| Mean: 556.2
# - **ACT 2017**: Median: 20.9 | Mean: 21.2
# - **ACT 2018**: Median: 20.7 | Mean: 21.1
#
# **_Reading and Writing (SAT only)_**
# - **SAT 2017**: Median: 559.0| Mean: 569.1
# - **SAT 2018**: Median: 552.0| Mean: 563.7
#
# **_Reading (ACT only)_**
# - **ACT 2017**: Median: 20.9| Mean: 22.0
# - **ACT 2018**: Median: 21.8| Mean: 22.0
#
# **_English (ACT only)_**
# - **ACT 2017**: Median: 20.7| Mean: 20.9
# - **ACT 2018**: Median: 20.2| Mean: 21.0
#
# **_Science (ACT only)_**
# - **ACT 2017**: Median: 21.3| Mean: 21.0
# - **ACT 2018**: Median: 21.1| Mean: 21.3

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: From the histograms above, I must say no, the data from this sample is not normally distributed. I explain why below.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: Rewriting my analysis for histograms above:
#
# "For Math and Reading (The 6 histograms at the last 2 rows), there are 2 peaks, suggesting a multimodal distribution. This is true for all the graphs except participation rates, which seem to come from some exponential distribution."
#
# While we can still make estimates from these data, we must sample more times before we can get a normal distribution. i.e. The standard number of 30 for the Central Limit Theorem may not hold. If we do keep it to around 30, the sample distribution cannot be guaranteed to be a normal distrubtion, forcing us to use alternative statistical analysis techniques like non-parametric techniques (e.g. student's t-distribution).

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: First, I must address an ambiguity in the question. The question asks whether it makes sense to conduct statistical inference given 'these data specifically', but it's unclear whether they mean **just** SAT and ACT 2017 data, or the data we have in final_df as a whole. I am assuming it is asking about final_df as a whole.
#
# Assuming we know nothing about the relationship between the two tests, I don't think it makes sense to do statistical inference with these data. At best, we can work out a correlation between the two, but we don't have access to plausible independent variables/features that might explain their correlation. This is because all we have are average score results, not factors like number of teachers, or number of test centres of each exam in a state.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# First, consider that the ACT scores are normalised between 1-36, while SAT data is not. They are also made by two different companies with no relation to one another, which means they use different testing methodologies. This makes for a poor case for comparison. I don't think we can run statistical inferences between SAT and ACT math scores.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ### The 3 states: California, Iowa, Hawaii
#
# I shall explore California, Iowa, and Hawaii. First, let me remind you of why these 3 states are interesting from our analysis. Below is a simplified table of participation rates for these 3 states, for 2017 and 2018. I've removed some of the numbers to prevent the table from becoming overwhelming.
#
# |**State**|**SAT 2017 Participation Rate**|**ACT 2017 Participation Rate**|**SAT 2018 Participation Rate**|**ACT 2018 Participation Rate**|
# |---|---|---|---|---|
# |California|53%|31%|-|-|
# |Hawaii|-|-|56%|89%|
# |Iowa|2%|67%|3%|68%|
#
# California had a relatively low participation rate for both SAT and ACT in 2017. This contrasts well with Hawaii, which had high participation rates for both exams in 2018. Yet one can easily say that both states are in a better state than Iowa, which had very low SAT participation rates for both 2017 and 2018, and had middling numbers for ACT participation rates.
#
# Looking into the education policies will help explain why these states have the participation rates they do.
#
# ### Section 1: Education in America
#
# 3 [National Acts](https://www.ed.gov/essa?src=rn/) are important to take note of.
#
# - Elementary and Secondary Education Act (ESEA), enacted in 196
# - No Child Left Behind Act (NCLB), enacted in 2002
# - Every Student Succeeds Act (ESSA), enacted in December 2015
#
# NCLB has had more time to be put into practice by the individual states, while ESSA builds on the ESEA. As ESSA was enacted in 2015, it is not relevant to the exams in 2017 and 2018 as bureucracy guarantees that more time was needed to implement the Act.
#
# As the [Iowa Department of Education summarises](https://www.educateiowa.gov/pk-12/no-child-left-behind-nclb):
#
# "NCLB provided federal money to schools to improve academic outcomes among students. The primary purpose of NCLB was to ensure that students in every public school achieved important learning goals while being educated in safe classrooms by well-prepared teachers."
#
# This means that there was an increase in funding money available for schools. However, not all states could access this money easily, as we will see in the case of California in Section 2.
#
# ### Section 2: California
#
# In a [2010 guide on reforming education in California for citizens](https://edpolicyinca.org/sites/default/files/2010_REFORMING_ED_IN_CA_WEB.pdf) by PACE, several problems were identified in California's education system.
#
# 1. **Lack of teachers**
# This is the most significant issue that plagues California. California had a worse student teacher ratio, at 21:1, compared to the national average of 16:1. It also lacked supportive educational staff, such as administrators, counselors, and librarians. Unless more incentives were provided to attract more professionals to education, especially the high-need schools, little progress can be made.
#
# 2. **Lack of awareness of testing or course requirements among secondary school students**
# This is more relevant to college level education, but students at secondary level have difficulties navigating the post-secondary educational landscape, suggesting a lack of familiarity of the importance of SAT or ACT in schools.
#
# 3. **High dropout rates among students**
# While some of the factors affecting dropout rate cannot be controlled, such as family background or income, PACE theorised that one controllable factor was that schools were not making links with students' desired career choices.
#
#
# 4. **Reliance on state funding**
# Education funding was complex and opaque, with only "a handful of experts" who knew how Californian schools were financed. There is a funding inequality gap between the good schools and the struggling ones and the opaque funding system exacerbates the problem. As mentioned in Section 1, there was an increase in federal (National) funding. California was mostly funded by the state, which meant that a significant source of revenue was not being used.
#
# ### Section 3: Hawaii
#
# Hawaii has a requirement for all high school graduates called the ['Personal Transition Plan'](http://www.hawaiipublicschools.org/DOE%20Forms/Graduation%20Brochures/PTP.pdf), which includes career planning the moment students enter 9th grade (on a 12 grade scale). This PTP is to assist students in transitioning away from high school. While entrance tests are not mandatory, the career plan likely helps students aspire towards post-secondary education.
#
# Hawaii began [administering the ACT to all students in 2013](http://www.hawaiipublicschools.org/ConnectWithUs/MediaRoom/PressReleases/Pages/2017-ACT-Results.aspx) (second paragraph). This explains the high 89% participation rate in 2018. Interestingly, [PrepScholar](https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice) shows that fewer states mandate the SAT than the ACT.
#
# I could find no evidence of the SAT being as important as the ACT. I only found that the public libraries [offer help for the ACT, SAT, and other entrance exams](http://www.hawaiipublicschools.org/ParentsAndStudents/SupportForStudents/HomeworkAndTestHelp/Pages/home.aspx).
#
# I conclude this section by suggesting that the resources they have to improve ACT scores simply carry over to the SAT, making it less costly to take both tests together.
#
# ### Section 4: Iowa
#
# Iowa's Department of Education website has [produced an 'Annual Condition of Education Report'](https://educateiowa.gov/data-and-reporting/education-statistics/annual-condition-education-report-pk-12) every year since 1998.
#
# This tracking alone suggests that there are significant efforts to improve, or at least maintain, the education system.
#
# According to the [2017](https://educateiowa.gov/sites/files/ed/documents/2017ConditionOfEducation_2.pdf) and [2018](https://educateiowa.gov/sites/files/ed/documents/2018ConditionOfEducation.pdf) annual reports, Iowa students do well in the ACT exams. Iowa only started tracking SAT scores in 2016-2017, suggesting that Iowa simply did not place much emphasis on SAT at all.
#
# The reports consistently mention 'Iowa Assessments' on page 153, which is tracked carefully. All public schools and "over 180 nonpublic schools" took part in the Iowa Assessments. However, these assessments are not accepted for college admissions.
#
# Page 182 of the 2018 report shows that more students are taking the Advanced Placement Classes, which are college level courses that high school students can take.
#
# Given the combination of good educational tracking, a simple lack of emphasis on the SAT, and increased participation in College level courses, the cause of middling participation rates could simply be _due to fewer students intending to pursue Postsecondary education_.
#
# My evidence for this lies on page 186 of the 2018 report. Table 5-18 clearly shows a decrease in students intending to take up further education. Barring a lack of further evidence, this seems to be the most significant factor involved.
#
# ### Sections 5, 6, 7, and 8
#
# See 'Conclusions and Recommendations' below.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# ### Section 5: Recommendations
#
# I conclude this analysis with the following findings:
#
# 1. **A good overall education infrastructure is paramount**
#
# Iowa and Hawaii tracks their education system closely, while it was more difficult to find policies for California. The lack of teachers and support staff seem to have the greatest effect on students being unable to sit the SAT or ACT.
#
# 2. **Encourage students to go for post-secondary education**
#
# A slow decline in the number of students who want to go for post-secondary education results in fewer students who sit the SAT and ACT. Giving help like Hawaii's PTP program (see Section 3) makes it more likely that students will take one of the two college entrance exams.
#
# 3. **Push policies that make either the SAT or ACT compulsory**
#
# While Hawaii is the only state in this analysis that mandated the ACT, its high participation rates in both exams suggests that the infrastructure built to improve results on one exam transfer over to the other. While it is in the College Board's interest to push for the SAT specifically, it might be worthwhile exploring a partnership with the ACT organization to encourage states to make one exam compulsory.
#
# ### Section 6: Applying the above recommendations to a struggling state: Oregon
#
# Early on in the exploratory analysis, I found that Oregon had a participation rate of less than 50% for both SAT and ACT in both 2017 and 2018. [This article by Oregon Live](https://www.oregonlive.com/education/2018/10/oregon_school_performance_rati.html) explains that teachers have a high chance of burn out as they serve "mostly low-income and students and children of color". The key issue is not the population being taught, but the lack of support for teachers in teaching challenging populations. The schools can endevour to put infrastructures in place to support teachers.
#
# With [low achievements in Maths](https://www.oregonlive.com/education/2016/01/oregon_ranks_low_in_education.html) and other scores, it's unlikely that students are aspiring to post-secondary education. Giving students the courage to overcome their circumstances will prove difficult. Perhaps pointing them to available resources, both online and offline, can help with this challenge.
#
# Finally, Pushing for compulsory SAT or ACT may seem ineffective for a state with low achievements. However, proper tracking of student grades will force Oregon to address weaknesses and fortify their strengths. As the overall goal is to improve student outcomes and improve their lives, working together with the ACT organization should be encouraged.
#
# ### Section 7: Important data to record
#
# The most important data to keep track of is students who aspire to post-secondary education, or reasons why students take the entrance exams. If the College Board can keep track of their reasons why tests are taken, we can come up with ways to encourage students to take the college entrance exam to reach their goals.
#
# ### Section 8: Conclusion to the analysis of this dataset
#
# In this analysis, I explored the SAT and ACT 2017 and 2018 datasets and identified states that were struggling and doing well. I explored the relationships between their individual score components, suggesting non-linear relationships drawn from multi-modal distributions. Participation rates seemed to be drawn from exponential distributions. All of this analysis provides the stepping stone for further modelling if so desired.
#
# I explored external reasons why California, Hawaii, and Iowa state did or did not have high participation rates. I applied these findings to another state, Oregon, which had less that 50% participation rates in either exams for both 2017 and 2018. I decided that keeping track of reasons why students take the entrance exams is important to track.
#
# Finally,further analysis with this dataset seems limited without independent variables/features that may be causally related to participation rates. In this dataset, participation rates affected composite/total scores, but composite/total scores cannot predict why participation rates are low or high.
